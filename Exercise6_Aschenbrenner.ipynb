# %% [markdown]
# # Exercise 6
# ## CIGALE
# - The configuration file was edited by using a text editor

# %%
from wand.image import Image as WImage
from subprocess import call

# %%
call(["pcigale", "init"])
# Out:
# 0

# %% [markdown]
# -> Edit configuration file

# %%
call(["pcigale", "genconf"])
# Out:
# 0

# %% [markdown]
# -> Edit configuration file: save_best_sed = True; save_pdf = True

# %%
call(["pcigale", "check"])
# Out:
# 0

# %%
call(["pcigale", "run"])
# Out:
# 0

# %%
call(["pcigale-plots", "sed"])
# Out:
# 0

# %%
img = WImage(filename="out/CGCG011076_best_model.pdf", resolution=200)
img
# Out:
# <wand.image.Image: 48b24dc 'PDF' (1280x960)>
